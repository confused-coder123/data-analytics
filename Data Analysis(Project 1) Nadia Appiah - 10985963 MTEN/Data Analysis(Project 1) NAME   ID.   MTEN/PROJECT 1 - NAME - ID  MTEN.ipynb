# %% [markdown]
# ### NAME :
# ### ID:
# ### DATE : 27 / 03 / 2023
# ### DEPARTMENT : MATERIALS SCIENCE & ENGINEERING
#    # RED WINE INVENTORY (PROJECT 1)
# ---

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
new_data = data.dropna()

# %%
new_data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
duplicates = new_data.duplicated()

# %%
number_duplicates = duplicates.sum()

# %%
number_duplicates
# Out:
# 0

# %% [markdown]
# ## Statistical inferences of entire dataset

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1591 non-null   int64
#  1   fixed acidity         1591 non-null   float64
#  2   volatile acidity      1591 non-null   float64
#  3   citric acid           1591 non-null   float64
#  4   residual sugar        1591 non-null   float64
#  5   chlorides             1591 non-null   float64
#  6   free sulfur dioxide   1591 non-null   float64
#  7   total sulfur dioxide  1591 non-null   float64
#  8   density               1591 non-null   float64
#  9   pH                    1591 non-null   float64
#  10  sulphates             1591 non-null   float64
#  11  alcohol               1591 non-null   float64
#  12  quality               1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %%
new_data.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %% [markdown]
# ## Statistical inferences of individual columns

# %%
new_data = data.rename(columns = {'fixed acidity':'fixed_acidity' , 'volatile acidity':'volatile_acidity','citric acid':'citric_acid','residual sugar':'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide','total sulfur dioxide':'total_sulfur_dioxide'})

# %%
new_data
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %% [markdown]
# ### Mean of individual columns

# %%
mean_fd = new_data.fixed_acidity.mean()
mean_vd = new_data.volatile_acidity.mean()
mean_cd = new_data.citric_acid.mean()
mean_rs = new_data.residual_sugar.mean()
mean_cl = new_data.chlorides.mean()
mean_fsd = new_data.free_sulfur_dioxide.mean()
mean_tsd = new_data.total_sulfur_dioxide.mean()
mean_ds = new_data.density.mean()
mean_pH = new_data.sulphates.mean()
mean_al = new_data.alcohol.mean()
mean_ql = new_data.quality.mean()

# %%
print(f'fixed_acidity: {mean_fd}')
print(f'volatile_acidity: {mean_vd}')
print(f'citric_acid: {mean_cd}')
print(f'residual_sugar: {mean_rs}')
print(f'chlorides: {mean_cl}')
print(f'free_sulfur_dioxide: {mean_fsd}')
print(f'total_sulfur_dioxide: {mean_tsd}')
print(f'density: {mean_ds}')
print(f'pH: {mean_pH}')
print(f'alcohol: {mean_al}')
print(f'quality: {mean_ql}')
# Out:
# fixed_acidity: 8.319875000000001
# volatile_acidity: 0.5277420362273579
# citric_acid: 0.271175
# residual_sugar: 2.5384447220487196
# chlorides: 0.0874874843554443
# free_sulfur_dioxide: 15.886875
# total_sulfur_dioxide: 46.52
# density: 0.9967456437500002
# pH: 0.6582198625858838
# alcohol: 10.42320424734541
# quality: 5.63625

# %% [markdown]
# ### Median of individual columns

# %%
median_fd = new_data.fixed_acidity.median()
median_vd = new_data.volatile_acidity.median()
median_cd = new_data.citric_acid.median()
median_rs = new_data.residual_sugar.median()
median_cl = new_data.chlorides.median()
median_fsd = new_data.free_sulfur_dioxide.median()
median_tsd = new_data.total_sulfur_dioxide.median()
median_ds = new_data.density.median()
median_pH = new_data.pH.median()
median_al = new_data.alcohol.median()
median_ql = new_data.quality.median()

# %%
print(f'fixed_acidity: {median_fd}')
print(f'volatile_acidity: {median_vd}')
print(f'citric_acid: {median_cd}')
print(f'residual_sugar: {median_rs}')
print(f'chlorides: {median_cl}')
print(f'free_sulfur_dioxide: {median_fsd}')
print(f'total_sulfur_dioxide: {median_tsd}')
print(f'density: {median_ds}')
print(f'pH: {median_pH}')
print(f'alcohol: {median_al}')
print(f'quality: {median_ql}')
# Out:
# fixed_acidity: 7.9
# volatile_acidity: 0.52
# citric_acid: 0.26
# residual_sugar: 2.2
# chlorides: 0.079
# free_sulfur_dioxide: 14.0
# total_sulfur_dioxide: 38.0
# density: 0.99675
# pH: 3.31
# alcohol: 10.2
# quality: 6.0

# %% [markdown]
# ### Mode of individual columns

# %%
mode_fd = new_data.fixed_acidity.mode()
mode_vd = new_data.volatile_acidity.mode()
mode_cd = new_data.citric_acid.mode()
mode_rs = new_data.residual_sugar.mode()
mode_cl = new_data.chlorides.mode()
mode_fsd = new_data.free_sulfur_dioxide.mode()
mode_tsd = new_data.total_sulfur_dioxide.mode()
mode_ds = new_data.density.mode()
mode_pH = new_data.pH.mode()
mode_al = new_data.alcohol.mode()
mode_ql = new_data.quality.mode()

# %%
print(f'fixed_acidity: {mode_fd}')
print(f'volatile_acidity: {mode_vd}')
print(f'citric_acid: {mode_cd}')
print(f'residual_sugar: {mode_rs}')
print(f'chlorides: {mode_cl}')
print(f'free_sulfur_dioxide: {mode_fsd}')
print(f'total_sulfur_dioxide: {mode_tsd}')
print(f'density: {mode_ds}')
print(f'pH: {mode_pH}')
print(f'alcohol: {mode_al}')
print(f'quality: {mode_ql}')
# Out:
# fixed_acidity: 0    7.2
# Name: fixed_acidity, dtype: float64
# volatile_acidity: 0    0.6
# Name: volatile_acidity, dtype: float64
# citric_acid: 0    0.0
# Name: citric_acid, dtype: float64
# residual_sugar: 0    2.0
# Name: residual_sugar, dtype: float64
# chlorides: 0    0.08
# Name: chlorides, dtype: float64
# free_sulfur_dioxide: 0    6.0
# Name: free_sulfur_dioxide, dtype: float64
# total_sulfur_dioxide: 0    28.0
# Name: total_sulfur_dioxide, dtype: float64
# density: 0    0.9972
# Name: density, dtype: float64
# pH: 0    3.3
# Name: pH, dtype: float64
# alcohol: 0    9.5
# Name: alcohol, dtype: float64
# quality: 0    5.0
# Name: quality, dtype: float64

# %% [markdown]
# ### Standard deviation of individual columns

# %%
std_fd = new_data.fixed_acidity.std()
std_vd = new_data.volatile_acidity.std()
std_cd = new_data.citric_acid.std()
std_rs = new_data.residual_sugar.std()
std_cl = new_data.chlorides.std()
std_fsd = new_data.free_sulfur_dioxide.std()
std_tsd = new_data.total_sulfur_dioxide.std()
std_ds = new_data.density.std()
std_pH = new_data.pH.std()
std_al = new_data.alcohol.std()
std_ql = new_data.quality.std()

# %%
print(f'fixed_acidity: {std_fd}')
print(f'volatile_acidity: {std_vd}')
print(f'citric_acid: {std_cd}')
print(f'residual_sugar: {std_rs}')
print(f'chlorides: {std_cl}')
print(f'free_sulfur_dioxide: {std_fsd}')
print(f'total_sulfur_dioxide: {std_tsd}')
print(f'density: {std_ds}')
print(f'pH: {std_pH}')
print(f'alcohol: {std_al}')
print(f'quality: {std_ql}')
# Out:
# fixed_acidity: 1.7400387405562694
# volatile_acidity: 0.17898116601503405
# citric_acid: 0.19474457060432368
# residual_sugar: 1.4091378630562335
# chlorides: 0.04707604028586422
# free_sulfur_dioxide: 10.45848651560053
# total_sulfur_dioxide: 32.97772344935955
# density: 0.0018872613578228613
# pH: 0.1543384314763553
# alcohol: 1.0654949345575428
# quality: 0.8073681561637429

# %% [markdown]
# ## Graphical Visualizations

# %%
sns.histplot(new_data['fixed_acidity'])
# Out:
# <Axes: xlabel='fixed_acidity', ylabel='Count'>

# %%
sns.histplot(new_data['volatile_acidity'])
# Out:
# <Axes: xlabel='volatile_acidity', ylabel='Count'>

# %%
sns.histplot(new_data['citric_acid'])
# Out:
# <Axes: xlabel='citric_acid', ylabel='Count'>

# %%
sns.histplot(new_data['residual_sugar'])
# Out:
# <Axes: xlabel='residual_sugar', ylabel='Count'>

# %%
sns.histplot(new_data['chlorides'])
# Out:
# <Axes: xlabel='chlorides', ylabel='Count'>

# %%
sns.histplot(new_data['free_sulfur_dioxide'])
# Out:
# <Axes: xlabel='free_sulfur_dioxide', ylabel='Count'>

# %%
sns.histplot(new_data['total_sulfur_dioxide'])
# Out:
# <Axes: xlabel='total_sulfur_dioxide', ylabel='Count'>

# %%
sns.histplot(new_data['density'])
# Out:
# <Axes: xlabel='density', ylabel='Count'>

# %%
sns.histplot(new_data['pH'])
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
sns.histplot(new_data['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
sns.histplot(new_data['quality'])
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
sns.barplot(x='quality', y='alcohol', data=new_data)
plt.show()

# %% [markdown]
# ## Hidden inferences

# %%
sns.scatterplot(x='pH', y='alcohol', data=new_data)
# Out:
# <Axes: xlabel='pH', ylabel='alcohol'>

# %%
sns.scatterplot(x='pH', y='fixed_acidity', data=new_data)
# Out:
# <Axes: xlabel='pH', ylabel='fixed_acidity'>

# %%
sns.scatterplot(x='pH', y='density', data=new_data)
# Out:
# <Axes: xlabel='pH', ylabel='density'>

# %%
sns.scatterplot(x='alcohol', y='residual_sugar', data=new_data)
# Out:
# <Axes: xlabel='alcohol', ylabel='residual_sugar'>

# %% [markdown]
# ## Data correlation

# %%
corr = new_data.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >
